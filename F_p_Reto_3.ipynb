# %% [markdown]
# <a href="https://colab.research.google.com/github/dianaq14/dianaq14/blob/main/F_p_Reto_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **RETO 3:** **Hallemos alsospechoso**
#
# **Objetivo**
# Desarrollar un programa en Python utilizando Replit que Muestre en qué sector de la ciudad se encuentra una persona que está utilizando un teléfono celular, acusada de Robar un diamante del museo de Moscú.
#
# **Descripción del Reto**
# La Interpol notificó que ella está en la Ciudad, y solicita el apoyo de las autoridades locales para capturarla, dicen que carga un pequeño bolso verde y que allí carga el diamante.
# Deniska Morkivake es una ladrona Internacional buscada por la Interpol como presunta culpable del hurto de un Diamante del museo de Moscú.
# Ella es una fotógrafa profesional, la excusa perfecta para entrar a los museos y cometer sus fechorías.
#
# Tienen identificado su teléfono celular, así que fácilmente se puede obtener la coordenada en donde ella se encuentra, triangulando la señal del telefono en donde se obtiene una coordenada (x , y) .
#
# ![image.png](data:image/png;base64,...)
#
# ¿Entonces qué debe hacer el programa en Python?
# Solicitar la coordenada en X y Y.
# Localizar en qué Sector se encuentra Deniska, por ejemplo si la coordenada es (6,4) se debe ejecutar lainstrucción tal cual print(“S4”)
# Si la coordenada se ubica exactamente sobre una línea roja Compartida, se deben indicar los dos sectores que comparten la posición de Deniska de la siguiente manera tal cual
# oprint(“Deniska está entre el Sector 1 y 2”)
# oprint("Deniska está entre el Sector 3 y 4")
# oprint("Deniska está entre el Sector 1 y 3")
# oprint("Deniska está entre el Sector 2 y 4")
# Si la coordenada está por fuera de la triangulación de las antenas, por ejemplo en (9,2), se debe ejecutar lasiguiente instrucción Tal Cual print(“Deniska ha escapado”)
# Deniska no tiene acceso a las antenas, es decir, que la coordenada de la antena no puede ser una coordenadaválida, de esa forma el programa no muestra nada
#
# Aspectos a tener en cuenta
# Utilice Replit para desarrollar el programa
# El programa debe utilizar una función def que tenga el nombre exacto sector yque reciba dos argumentos (x,y) , de la siguiente manera:
# ![image.png](data:image/png;base64,...)
#
# Implemente IF o IF Else, o las condiciones que requiera.
# El código final se debe cargar en Moodle, el cual se autocalificaráautomáticamente.
# Finalmente, es importante que la función ![image.png](data:image/png;base64,...)
# no Retorne ningún valor, es decir, se debe imprimir todo desde la función.

# %%
def sector(x,y):
 
    if x== 2 and y == 9:
      print()

    elif x== 8 and y == 9:
      print()

    elif x== 5 and y == 6:
      print()

    elif x== 2 and y == 3:
      print()

    elif x== 8 and y == 3:
      print()


    elif x == 5 and y > 6 and y <= 9:
      print("Deniska está entre el Sector 1 y 2")
    
    elif x == 5 and y < 6 and y >= 3:
      print("Deniska está entre el Sector 3 y 4")

    elif x >= 2 and x < 5 and y == 6:
      print("Deniska está entre el Sector 1 y 3")
    
    elif x > 5 and x <= 8 and y == 6:
      print("Deniska está entre el Sector 2 y 4")  

    
    elif x >= 2 and x < 5 and y > 6 and y <= 9:
      print("S1")

    elif x >= 5 and x <= 8 and y > 6 and y <= 9:
      print("S2")
    
    elif x >= 2 and x < 5 and y >= 3 and y < 6:
      print("S3")

    elif x >= 5 and x <= 8 and y >= 3 and y < 6:
      print("S4")      

    else:
      print("Deniska ha escapado")

x= float(input("ingrese las coordenadas de X:" ))
y= float(input("ingrese las coordenadas de Y:" ))
sector(x,y)
